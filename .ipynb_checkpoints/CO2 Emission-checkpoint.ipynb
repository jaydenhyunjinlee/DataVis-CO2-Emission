# %% [markdown]
# ## Data Visualization using CO2 Emission dataset
#
# ### This notebook demonstrates all plots I created using `matplotlib.pyplot` and `altair` API that explains trends and shows findings from CO2 Emission dataset

# %%
# Autoreloader magic function in Jupyter environment

# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import sys
import altair as alt

# %matplotlib notebook

# %%
# Import the implementations
sys.path.insert(0, 'src')

from load_data import load_data
from global_emission_trend import global_emission_trend
from most_developed_countries_co2 import most_developed_countries_co2
from most_contributors import most_contributors
from usa_and_china import usa_and_china

# %%
# Prepare dataset to plot bar chart with
# Set absolute path to the dataset

data_loc = 'data/co2_emission.csv'
fp = os.path.join(os.getcwd(), data_loc)

co2 = load_data(fp, option='bargraph')
display(co2.head())
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/groupby/generic.py:303: FutureWarning: Dropping invalid columns in SeriesGroupBy.agg is deprecated. In a future version, a TypeError will be raised. Before calling .agg, select only columns which should be valid for the aggregating function.
#   results[key] = self.aggregate(func)
#       Average Annual CO2 Emission
# Year
# 1751                 1.558421e+06
# 1752                 1.559032e+06
# 1753                 1.559032e+06
# 1754                 1.559643e+06
# 1755                 1.560253e+06

# %% [markdown]
# ### Change in average global CO2 emission rate

# %%
# Plot bar chart using `global_emission_trend()`

ax = global_emission_trend(co2, color='green', figsize=(8,6))
# Out:
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
# ### CO2 Emission rates in most-developed nations in each continent

# %%
data = load_data(fp, option='linegraph')

# Transformed for visualization
display(data.head())
# Out:
#    Year          Entity  Annual CO2 Emission
# 0  1751           China                  0.0
# 1  1751  United Kingdom            9350528.0
# 2  1751   United States                  0.0
# 3  1752           China                  0.0
# 4  1752  United Kingdom            9354192.0

# %%
vis = most_developed_countries_co2(data)
display(vis)
# Out:
# alt.Chart(...)

# %% [markdown]
# ### Top five nations that emitted the *most* CO2 from 2010 to 2017 and amount of their CO2 emission

# %%
data = load_data(fp)
display(data.head()) # Raw format
# Out:
#         Entity Code  Year  Annual CO₂ emissions (tonnes )
# 0  Afghanistan  AFG  1949                         14656.0
# 1  Afghanistan  AFG  1950                         84272.0
# 2  Afghanistan  AFG  1951                         91600.0
# 3  Afghanistan  AFG  1952                         91600.0
# 4  Afghanistan  AFG  1953                        106256.0

# %%
vis = most_contributors(data)
# Out:
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
# ### How much CO2 emissions USA and China <font color=orange>*ALONE*</font> contributed to global CO2 emissions in 2017

# %%
data = load_data(fp)
display(data.head())
# Out:
#         Entity Code  Year  Annual CO₂ emissions (tonnes )
# 0  Afghanistan  AFG  1949                         14656.0
# 1  Afghanistan  AFG  1950                         84272.0
# 2  Afghanistan  AFG  1951                         91600.0
# 3  Afghanistan  AFG  1952                         91600.0
# 4  Afghanistan  AFG  1953                        106256.0

# %%
pie = usa_and_china(data)
# Out:
# <img src="data:image/png;base64,..." width="800">
